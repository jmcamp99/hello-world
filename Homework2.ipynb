# %%
# 1
import pandas as pd
dictionary = pd.read_csv('Documents/KStateSpring2025/MLAS350/dictionary.csv')
print(type(dictionary))
dictionary.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
# a) Print the column names
dictionary.columns
# Out:
# Index(['Country', 'Code', 'Population', 'GDP per Capita'], dtype='object')

# %%
# b) Print the shape
dictionary.shape
# Out:
# (201, 4)

# %%
# c) Check if there are any missing values or NaN in the columns. Print the missing or NaN count for each column.
dictionary.isnull().sum()
# Out:
# Country            0
# Code               0
# Population         5
# GDP per Capita    25
# dtype: int64

# %%
# d) Find the mean of the Population and mean of GDP per Capita and print the values.
print(dictionary['Population'].describe())
print('----------------------------------------')
print('The Population mean is: 3.722825e+07')
# Out:
# count    1.960000e+02
# mean     3.722825e+07
# std      1.399655e+08
# min      1.022200e+04
# 25%      1.638278e+06
# 50%      7.450124e+06
# 75%      2.557454e+07
# max      1.371220e+09
# Name: Population, dtype: float64
# ----------------------------------------
# The Population mean is: 3.722825e+07

# %%
# d) Part 2
print(dictionary['GDP per Capita'].describe())
print('-----------------------------------------')
print('The GDP per Capita mean is: 12882.556131')
# Out:
# count       176.000000
# mean      12882.556131
# std       17747.141203
# min         277.068309
# 25%        1781.096847
# 50%        5233.583395
# 75%       15494.683646
# max      101449.968168
# Name: GDP per Capita, dtype: float64
# -----------------------------------------
# The GDP per Capita mean is: 12882.556131

# %%
# e) Propose a method to fill the missing values or NaN for each. Explain why you chose this method.

'''
  Answer:  I would use fillna and the mean method to fill in the missing values so that I would have 
           an average of the column for each missing value to keep the numbers from skewing
           too low as they could if I filled in the missing values with zero. I think it would give
           me a better idea of how it could be if those values were there. It depends on the 
           result I am looking for.
'''
print(dictionary['GDP per Capita'].fillna(dictionary['GDP per Capita'].mean))
# Out:
# 0                                             594.323081
# 1                                            3945.217582
# 2                                            4206.031232
# 3      <bound method Series.mean of 0       594.32308...
# 4      <bound method Series.mean of 0       594.32308...
#                              ...
# 196                                          2111.138024
# 197    <bound method Series.mean of 0       594.32308...
# 198                                          1406.291651
# 199                                          1304.879014
# 200                                           924.143819
# Name: GDP per Capita, Length: 201, dtype: object
